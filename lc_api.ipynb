# %% [markdown]
# # Services Available

# %% [markdown]
# 1. Transfer funds
# 2. Summary
# 3. Cancel transfers
# 4. Submit order
# 5. Create portfolio
# 6. Listed Loans
#
# One request per second limit.

# %% [markdown]
# # Doing it

# %%
import os
credentials = os.environ['LENDING_CLUB_API']
investor_id = 5809260
import sys
from scripts.model import create_matrix

# %%
import requests

# %%
 headers = {'Authorization': credentials}

# %%
r = requests.get('https://api.lendingclub.com/api/investor/v1/loans/listing?showAll=true',
                headers=headers)

# %%
investor_id = 5809260

# %%
loans = r.json()['loans']

# %%
import pandas as pd
df = pd.DataFrame(loans)

# %% [markdown]
# ## Predicting the Values

# %%
from sklearn.externals import joblib
from scripts.model import create_matrix
from scripts.clean_data import clean_columns, category_processing

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Load the Model
# 2. Load the df
# 3. turn the df into the same matrix as before
# 4. Predict the values

# %%
model = joblib.load('model/rf_model.pkl')

# %%
model.feature_importances_
# Out:
# array([  0.00000000e+00,   7.74582427e-04,   4.25484043e-03,
#          6.44435277e-03,   6.53594083e-03,   5.81373876e-03,
#          7.23756605e-03,   9.69437071e-03,   7.79777132e-03,
#          3.37990732e-03,   5.42204621e-03,   5.37577858e-03,
#          5.37992256e-03,   5.31156625e-03,   5.16631500e-03,
#          5.18567283e-03,   4.77221367e-03,   4.20083932e-03,
#          3.78652367e-03,   3.77130329e-03,   3.79652276e-03,
#          1.59038754e-03,   1.93192443e-03,   2.80524110e-03,
#          5.93305235e-03,   1.10029447e-02,   6.64117419e-03,
#          2.06063161e-02,   5.17116793e-03,   4.68428681e-03,
#          6.32563842e-04,   4.06048610e-03,   2.70847004e-03,
#          3.55962448e-03,   3.24787051e-03,   2.63796509e-03,
#          4.50271661e-03,   1.01960780e-03,   7.55389735e-03,
#          2.24254695e-03,   1.90953276e-03,   4.75676651e-03,
#          3.73940889e-03,   5.04669678e-03,   5.96372016e-03,
#          3.98323386e-03,   4.06043452e-03,   1.62563665e-03,
#          2.36067448e-03,   6.51317447e-03,   4.98936292e-03,
#          3.58055276e-03,   5.87166698e-05,   2.88236881e-05,
#          4.82920832e-03,   3.76639215e-03,   3.72562510e-03,
#          4.15857480e-03,   4.55203774e-03,   5.05050618e-03,
#          5.92309918e-03,   0.00000000e+00,   5.38034422e-03,
#          5.00965573e-03,   5.18729955e-03,   9.69191784e-04,
#          1.85519541e-03,   5.59645682e-03,   1.20081458e-04,
#          2.54244597e-03,   6.19674622e-03,   3.37746488e-03,
#          5.61654652e-03,   6.09805805e-03,   5.48422151e-03,
#          4.16997673e-03,   4.15561310e-03,   5.34717533e-03,
#          3.00973586e-03,   3.55371660e-03,   1.54798974e-03,
#          3.76558489e-03,   4.83384809e-03,   4.07089819e-03,
#          5.83930206e-03,   1.23766912e-03,   4.54882026e-03,
#          4.13257279e-03,   2.05389039e-03,   1.55943143e-03,
#          5.18507607e-02,   8.85127538e-02,   6.32325411e-02,
#          2.37813949e-02,   2.17118212e-02,   9.22657479e-03,
#          7.20825517e-02,   4.02324369e-02,   2.07878877e-03,
#          1.43979076e-02,   4.46862085e-02,   4.02558471e-02,
#          7.94953167e-02,   6.39389663e-02])

# %% [markdown]
# ## Compatibility Issues

# %%
import re
def convert(name):
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

# %%
df.columns = [convert(i) for i in df.columns]

# %%
import numpy as np

# %%
df = df.rename(columns={'collections12_mths_ex_med': 
    'collections_12_mths_ex_med', 'loan_amount': 'loan_amnt',
    'delinq2_yrs': 'delinq_2yrs', 'inq_last6_mths':'inq_last_6mths',
                       'addr_zip':'zip_code'})

# %%
df['ratio_mth_inc_all_payments'] = (df.installment + df.revol_bal * .02) / (df.annual_inc / 12)

# %%
df.columns
# Out:
# Index(['acc_now_delinq', 'acc_open_past24_mths', 'accept_d', 'addr_state',
#        'zip_code', 'annual_inc', 'annual_inc_joint', 'application_type',
#        'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within12_mths',
#        'collections_12_mths_ex_med', 'credit_pull_d', 'delinq_2yrs',
#        'delinq_amnt', 'desc', 'dti', 'dti_joint', 'earliest_cr_line',
#        'emp_length', 'emp_title', 'exp_d', 'exp_default_rate',
#        'fico_range_high', 'fico_range_low', 'funded_amount', 'grade',
#        'home_ownership', 'id', 'ils_exp_d', 'initial_list_status',
#        'inq_last_6mths', 'installment', 'int_rate', 'investor_count',
#        'is_inc_v', 'is_inc_v_joint', 'list_d', 'loan_amnt', 'member_id',
#        'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op',
#        'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_last_delinq',
#        'mths_since_last_major_derog', 'mths_since_last_record',
#        'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever120_ppd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
#        'num_rev_accts', 'num_rev_tl_bal_gt0', 'num_sats', 'num_tl120dpd2m',
#        'num_tl30dpd', 'num_tl90g_dpd24m', 'num_tl_op_past12m', 'open_acc',
#        'pct_tl_nvr_dlq', 'percent_bc_gt75', 'pub_rec', 'pub_rec_bankruptcies',
#        'purpose', 'review_status', 'review_status_d', 'revol_bal',
#        'revol_util', 'service_fee_rate', 'sub_grade', 'tax_liens', 'term',
#        'tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_acc',
#        'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit',
#        'total_rev_hi_lim', 'year_issued', 'month_issued', 'delinq',
#        'ratio_mth_inc_all_payments'],
#       dtype='object')

# %% [markdown]
# ## Processing

# %%
df.emp_length = df.emp_length / 12

# %%
import sys
sys.path
# Out:
# ['',
#  '/Users/Will/Devel/metis/lc/“',
#  '/Users/Will/Devel',
#  '/Users/Will/scripts”',
#  '/Users/Will/anaconda/envs/py34/lib/python34.zip',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/plat-darwin',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/lib-dynload',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/Sphinx-1.3.1-py3.4.egg',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/setuptools-18.4-py3.4.egg',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/site-packages',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/aeosa',
#  '/Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/IPython/extensions',
#  '/Users/Will/.ipython',
#  '../scripts',
#  'scripts']

# %%
model.create_matrix()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-18549dde018c> in <module>()
# ----> 1 model.create_matrix()
#
# AttributeError: 'module' object has no attribute 'create_matrix'

# %%
from app.process_api import process_columns, rename_columns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-327702823aad> in <module>()
# ----> 1 from app.process_api import process_columns, rename_columns
#
# /Users/Will/Devel/metis/lc/app/process_api.py in <module>()
#      15
#      16 sys.path.append("../scripts")
# ---> 17 from model import create_matrix
#      18 from clean_data import clean_columns, category_processing
#      19
#
# ImportError: cannot import name 'create_matrix'

# %%
df = clean_columns(df)
df = category_processing(df)
# Out:
# Cleaning Columns. This takes minutes due to a large number of string operations.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-935448fb355b> in <module>()
# ----> 1 df = clean_columns(df)
#       2 df = category_processing(df)
#
# /Users/Will/Devel/metis/lc/scripts/clean_data.py in clean_columns(df)
#      67
#      68     # Change employment length to inits.
# ---> 69     df.emp_length = df.emp_length.replace({'10+ years': 20, '< 1 year': 0, '1 year': 1})
#      70     df.emp_length = df.emp_length.replace({'{} years'.format(i): i
#      71                                            for i in range(1,10)})
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    2917
#    2918             return self.replace(to_replace, value, inplace=inplace,
# -> 2919                                 limit=limit, regex=regex)
#    2920         else:
#    2921
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    2960                                                        dest_list=value,
#    2961                                                        inplace=inplace,
# -> 2962                                                        regex=regex)
#    2963
#    2964                 else:  # [NA, ''] -> 0
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/internals.py in replace_list(self, src_list, dest_list, inplace, regex)
#    2772             return _possibly_compare(values, getattr(s, 'asm8', s),
#    2773                                      operator.eq)
# -> 2774         masks = [comp(s) for i, s in enumerate(src_list)]
#    2775
#    2776         result_blocks = []
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    2772             return _possibly_compare(values, getattr(s, 'asm8', s),
#    2773                                      operator.eq)
# -> 2774         masks = [comp(s) for i, s in enumerate(src_list)]
#    2775
#    2776         result_blocks = []
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/internals.py in comp(s)
#    2771                 return isnull(values)
#    2772             return _possibly_compare(values, getattr(s, 'asm8', s),
# -> 2773                                      operator.eq)
#    2774         masks = [comp(s) for i, s in enumerate(src_list)]
#    2775
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/internals.py in _possibly_compare(a, b, op)
#    4152             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4153
# -> 4154         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4155     return res
#    4156
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'

# %%
df
# Out:
#      acc_now_delinq  acc_open_past24_mths                       accept_d  \
# 0                 0                     3  2015-10-25T17:13:15.000-07:00
# 1                 0                     2  2015-10-26T13:34:14.000-07:00
# 2                 0                     0  2015-10-26T09:58:32.000-07:00
# 3                 0                     6  2015-10-27T04:34:13.000-07:00
# 4                 0                     4  2015-10-26T18:54:58.000-07:00
# 5                 0                     5  2015-10-25T18:19:43.000-07:00
# 6                 0                     9  2015-10-26T15:49:22.000-07:00
# 7                 0                     1  2015-10-26T12:30:22.000-07:00
# 8                 0                     3  2015-10-25T15:18:03.000-07:00
# 9                 0                     5  2015-10-27T15:21:00.000-07:00
# 10                0                     1  2015-10-25T12:01:37.000-07:00
# 11                0                    10  2015-10-26T19:29:00.000-07:00
# 5           FL      331       25000               NaN       INDIVIDUAL
# 6           CA      925       28000               NaN       INDIVIDUAL
# 7           NY      112       77000               NaN       INDIVIDUAL
# 8           CO      809       50500               NaN       INDIVIDUAL
# 9           KS      666       48276               NaN       INDIVIDUAL
# 10          HI      967       40000               NaN       INDIVIDUAL
# 11          NY      117      155000               NaN       INDIVIDUAL
# 12          NV      890       40217               NaN       INDIVIDUAL
# 13          NY      112      100000               NaN       INDIVIDUAL
# 14          NV      891       72000               NaN       INDIVIDUAL
# 15          OR      970       48000               NaN       INDIVIDUAL
# 16          OH      443       61450               NaN       INDIVIDUAL
# 17          NC      278       50000            120000            JOINT
# 18          FL      336       35000               NaN       INDIVIDUAL
# 19          PA      189       29000               NaN       INDIVIDUAL
# 20          NY      114       75000               NaN       INDIVIDUAL
# 21          CA      914       50400               NaN       INDIVIDUAL
# 22          MI      481       60000               NaN       INDIVIDUAL
# 23          LA      701       35000               NaN       INDIVIDUAL
# 24          NC      270       30000               NaN       INDIVIDUAL
# 25          CA      946       45000               NaN       INDIVIDUAL
# 26          IL      600       26000               NaN       INDIVIDUAL
# 27          GA      302       40000               NaN       INDIVIDUAL
# 28          WV      247       98000               NaN       INDIVIDUAL
# 29          AZ      852      180000               NaN       INDIVIDUAL
# ..         ...      ...         ...               ...              ...
# 570         AL      351       80000               NaN       INDIVIDUAL
# 571         GA      301       60000               NaN       INDIVIDUAL
# 572         MA      014      280000               NaN       INDIVIDUAL
# 573         GA      301      131000               NaN       INDIVIDUAL
# 574         FL      325      138000               NaN       INDIVIDUAL
# 575         NY      117       72000               NaN       INDIVIDUAL
# 576         MO      655       71000               NaN       INDIVIDUAL
# 577         PA      154       82000               NaN       INDIVIDUAL
# 578         CA      913      156000               NaN       INDIVIDUAL
# 579         MI      480       85000               NaN       INDIVIDUAL
# 580         SC      295      100000               NaN       INDIVIDUAL
# 581         MD      210       80000               NaN       INDIVIDUAL
# 582         CA      921       83200               NaN       INDIVIDUAL
# 583         CO      800       80000               NaN       INDIVIDUAL
# 584         TX      765      107000               NaN       INDIVIDUAL
# 585         MN      554      150000               NaN       INDIVIDUAL
# 586         GA      303      120000               NaN       INDIVIDUAL
# 587         CA      945      112000               NaN       INDIVIDUAL
# 588         WA      983      144000               NaN       INDIVIDUAL
# 589         RI      028       83200               NaN       INDIVIDUAL
# 590         NY      104       80000               NaN       INDIVIDUAL
# 591         TX      775      300000               NaN       INDIVIDUAL
# 592         TX      750      120000               NaN       INDIVIDUAL
# 593         TX      770      105000               NaN       INDIVIDUAL
# 594         FL      334       80000               NaN       INDIVIDUAL
# 595         CT      068      129000               NaN       INDIVIDUAL
# 596         FL      328       93000               NaN       INDIVIDUAL
# 597         GA      306      122000               NaN       INDIVIDUAL
# 598         MI      480       90000               NaN       INDIVIDUAL
# 599         IN      460      200000               NaN       INDIVIDUAL
#
#      avg_cur_bal  bc_open_to_buy            ...              tot_hi_cred_lim  \
# 0            805            2077            ...                         9200
# 10                    0.123939
# 11                    0.088750
# 12                    0.125517
# 13                    0.173090
# 14                    0.152520
# 15                    0.129827
# 16                    0.101689
# 17                    0.065846
# 18                    0.163941
# 19                    0.148680
# 20                    0.089070
# 21                    0.179964
# 22                    0.226562
# 23                    0.078480
# 24                    0.092628
# 25                    0.130339
# 26                    0.247357
# 27                    0.091992
# 28                    0.172236
# 29                    0.076599
# ..                         ...
# 570                   0.173004
# 571                   0.277366
# 572                   0.069624
# 573                   0.282825
# 574                   0.095665
# 575                   0.153172
# 576                   0.243468
# 577                   0.241320
# 578                   0.090765
# 579                   0.248178
# 580                   0.162373
# 581                   0.454030
# 582                   0.161546
# 583                   0.224548
# 584                   0.198096
# 585                   0.131603
# 586                   0.126916
# 587                   0.216004
# 588                   0.128657
# 589                   0.219744
# 590                   0.169983
# 591                   0.053203
# 592                   0.175766
# 593                   0.229414
# 594                   0.302897
# 595                   0.349749
# 596                   0.190939
# 597                   0.123704
# 598                   0.127560
# 599                   0.274792
#
# [600 rows x 93 columns]

# %% [markdown]
# ## Converting the Matrix

# %%
y, X = create_matrix(df)

# %%
df.home_ownership.value_counts()
# Out:
# RENT        260
# MORTGAGE    256
# OWN          84
# Name: home_ownership, dtype: int64

# %%
X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-b5ab17e92531> in <module>()
# ----> 1 X.columns
#
# NameError: name 'X' is not defined

# %%
df.home_ownership = df.home_ownership.astype('category')

# %%
for i in X.columns:
    print(i)
# Out:
# Intercept
# C(home_ownership)[T.OWN]
# C(home_ownership)[T.RENT]
# C(grade)[T.B]
# C(grade)[T.C]
# C(grade)[T.D]
# C(grade)[T.E]
# C(grade)[T.G]
# C(purpose)[T.credit_card]
# C(purpose)[T.debt_consolidation]
# C(purpose)[T.home_improvement]
# C(purpose)[T.house]
# C(purpose)[T.major_purchase]
# C(purpose)[T.medical]
# C(purpose)[T.moving]
# C(purpose)[T.other]
# C(purpose)[T.renewable_energy]
# C(purpose)[T.small_business]
# C(purpose)[T.vacation]
# C(addr_state)[T.AL]
# C(addr_state)[T.AR]
# C(addr_state)[T.AZ]
# C(addr_state)[T.CA]
# C(addr_state)[T.CO]
# C(addr_state)[T.CT]
# C(addr_state)[T.DC]
# C(addr_state)[T.DE]
# C(addr_state)[T.FL]
# C(addr_state)[T.GA]
# C(addr_state)[T.HI]
# C(addr_state)[T.IL]
# C(addr_state)[T.IN]
# C(addr_state)[T.KS]
# C(addr_state)[T.KY]
# C(addr_state)[T.LA]
# C(addr_state)[T.MA]
# C(addr_state)[T.MD]
# C(addr_state)[T.ME]
# C(addr_state)[T.MI]
# C(addr_state)[T.MN]
# C(addr_state)[T.MO]
# C(addr_state)[T.MS]
# C(addr_state)[T.MT]
# C(addr_state)[T.NC]
# C(addr_state)[T.ND]
# C(addr_state)[T.NE]
# C(addr_state)[T.NH]
# C(addr_state)[T.NJ]
# C(addr_state)[T.NV]
# C(addr_state)[T.NY]
# C(addr_state)[T.OH]
# C(addr_state)[T.OK]
# C(addr_state)[T.OR]
# C(addr_state)[T.PA]
# C(addr_state)[T.RI]
# C(addr_state)[T.SC]
# C(addr_state)[T.SD]
# C(addr_state)[T.TN]
# C(addr_state)[T.TX]
# C(addr_state)[T.UT]
# C(addr_state)[T.VA]
# C(addr_state)[T.WA]
# C(addr_state)[T.WI]
# C(addr_state)[T.WV]
# C(addr_state)[T.WY]
# earliest_cr_line[T.1969-02-26T16:00:00.000-08:00]
# earliest_cr_line[T
09-26T17:00:00.000-07:00]
# earliest_cr_line[T.1996-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.1996-10-24T17:00:00.000-07:00]
# earliest_cr_line[T.1996-10-25T17:00:00.000-07:00]
# earliest_cr_line[T.1996-11-22T16:00:00.000-08:00]
# earliest_cr_line[T.1996-11-27T16:00:00.000-08:00]
# earliest_cr_line[T.1996-12-26T16:00:00.000-08:00]
# earliest_cr_line[T.1997-01-25T16:00:00.000-08:00]
# earliest_cr_line[T.1997-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.1997-02-23T16:00:00.000-08:00]
# earliest_cr_line[T.1997-03-26T16:00:00.000-08:00]
# earliest_cr_line[T.1997-04-20T17:00:00.000-07:00]
# earliest_cr_line[T.1997-04-24T17:00:00.000-07:00]
# earliest_cr_line[T.1997-05-21T17:00:00.000-07:00]
# earliest_cr_line[T.1997-05-25T17:00:00.000-07:00]
# earliest_cr_line[T.1997-06-25T17:00:00.000-07:00]
# earliest_cr_line[T.1997-06-26T17:00:00.000-07:00]
# earliest_cr_line[T.1997-07-25T17:00:00.000-07:00]
# earliest_cr_line[T.1997-08-26T17:00:00.000-07:00]
# earliest_cr_line[T.1997-10-26T16:00:00.000-08:00]
# earliest_cr_line[T.1997-10-27T16:00:00.000-08:00]
# earliest_cr_line[T.1997-11-22T16:00:00.000-08:00]
# earliest_cr_line[T.1997-11-26T16:00:00.000-08:00]
# earliest_cr_line[T.1997-12-24T16:00:00.000-08:00]
# earliest_cr_line[T.1998-01-23T16:00:00.000-08:00]
# earliest_cr_line[T.1998-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.1998-02-26T16:00:00.000-08:00]
# earliest_cr_line[T.1998-03-24T16:00:00.000-08:00]
# earliest_cr_line[T.1998-03-25T16:00:00.000-08:00]
# earliest_cr_line[T.1998-04-21T17:00:00.000-07:00]
# earliest_cr_line[T.1998-04-23T17:00:00.000-07:00]
# earliest_cr_line[T.1998-04-26T17:00:00.000-07:00]
# earliest_cr_line[T.1998-05-23T17:00:00.000-07:00]
# earliest_cr_line[T.1998-06-25T17:00:00.000-07:00]
# earliest_cr_line[T.1998-06-26T17:00:00.000-07:00]
# earliest_cr_line[T.1998-06-27T17:00:00.000-07:00]
# earliest_cr_line[T.1998-08-24T17:00:00.000-07:00]
# earliest_cr_line[T.1998-08-26T17:00:00.000-07:00]
# earliest_cr_line[T.1998-08-27T17:00:00.000-07:00]
# earliest_cr_line[T.1998-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.1998-10-21T17:00:00.000-07:00]
# earliest_cr_line[T.1998-10-25T16:00:00.000-08:00]
# earliest_cr_line[T.1998-10-26T16:00:00.000-08:00]
# earliest_cr_line[T.1998-10-27T16:00:00.000-08:00]
# earliest_cr_line[T.1998-11-19T16:00:00.000-08:00]
# earliest_cr_line[T.1998-11-27T16:00:00.000-08:00]
# earliest_cr_line[T.1998-12-20T16:00:00.000-08:00]
# earliest_cr_line[T.1998-12-23T16:00:00.000-08:00]
# earliest_cr_line[T.1999-01-26T16:00:00.000-08:00]
# earliest_cr_line[T.1999-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.1999-02-24T16:00:00.000-08:00]
# earliest_cr_line[T.1999-02-25T16:00:00.000-08:00]
# earliest_cr_line[T.1999-03-24T16:00:00.000-08:00]
# earliest_cr_line[T.1999-03-26T16:00:00.000-08:00]
# earliest_cr_line[T.1999-03-27T16:00:00.000-08:00]
# earliest_cr_line[T.1999-04-23T17:00:00.000-07:00]
# earliest_cr_line[T.1999-04-27T17:00:00.000-07:00]
# earliest_cr_line[T.1999-05-24T17:00:00.000-07:00]
# earliest_cr_line[T.1999-07-27T17:00:00.000-07:00]
# earliest_cr_line[T.1999-08-23T17:00:00.000-07:00]
# earliest_cr_line[T.1999-08-26T17:00:00.000-07:00]
# earliest_cr_line[T.1999-08-27T17:00:00.000-07:00]
# earliest_cr_line[T.1999-09-25T17:00:00.000-07:00]
# earliest_cr_line[T.1999-09-26T17:00:00.000-07:00]
# earliest_cr_line[T.1999-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.1999-10-26T17:00:00.000-07:00]
# earliest_cr_line[T
08-26T17:00:00.000-07:00]
# earliest_cr_line[T.2002-09-21T17:00:00.000-07:00]
# earliest_cr_line[T.2002-09-24T17:00:00.000-07:00]
# earliest_cr_line[T.2002-09-25T17:00:00.000-07:00]
# earliest_cr_line[T.2002-09-26T17:00:00.000-07:00]
# earliest_cr_line[T.2002-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.2002-10-22T17:00:00.000-07:00]
# earliest_cr_line[T.2002-10-24T17:00:00.000-07:00]
# earliest_cr_line[T.2002-10-26T17:00:00.000-07:00]
# earliest_cr_line[T.2002-11-26T16:00:00.000-08:00]
# earliest_cr_line[T.2002-12-26T16:00:00.000-08:00]
# earliest_cr_line[T.2003-01-21T16:00:00.000-08:00]
# earliest_cr_line[T.2003-01-26T16:00:00.000-08:00]
# earliest_cr_line[T.2003-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.2003-02-25T16:00:00.000-08:00]
# earliest_cr_line[T.2003-03-22T16:00:00.000-08:00]
# earliest_cr_line[T.2003-03-25T16:00:00.000-08:00]
# earliest_cr_line[T.2003-03-26T16:00:00.000-08:00]
# earliest_cr_line[T.2003-04-21T17:00:00.000-07:00]
# earliest_cr_line[T.2003-05-25T17:00:00.000-07:00]
# earliest_cr_line[T.2003-05-26T17:00:00.000-07:00]
# earliest_cr_line[T.2003-06-22T17:00:00.000-07:00]
# earliest_cr_line[T.2003-06-26T17:00:00.000-07:00]
# earliest_cr_line[T.2003-06-27T17:00:00.000-07:00]
# earliest_cr_line[T.2003-07-26T17:00:00.000-07:00]
# earliest_cr_line[T.2003-08-21T17:00:00.000-07:00]
# earliest_cr_line[T.2003-08-26T17:00:00.000-07:00]
# earliest_cr_line[T.2003-08-27T17:00:00.000-07:00]
# earliest_cr_line[T.2003-09-24T17:00:00.000-07:00]
# earliest_cr_line[T.2003-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.2003-10-25T17:00:00.000-07:00]
# earliest_cr_line[T.2003-10-26T16:00:00.000-08:00]
# earliest_cr_line[T.2003-10-27T16:00:00.000-08:00]
# earliest_cr_line[T.2003-11-24T16:00:00.000-08:00]
# earliest_cr_line[T.2003-11-27T16:00:00.000-08:00]
# earliest_cr_line[T.2003-12-26T16:00:00.000-08:00]
# earliest_cr_line[T.2003-12-27T16:00:00.000-08:00]
# earliest_cr_line[T.2004-01-21T16:00:00.000-08:00]
# earliest_cr_line[T.2004-01-26T16:00:00.000-08:00]
# earliest_cr_line[T.2004-02-25T16:00:00.000-08:00]
# earliest_cr_line[T.2004-02-26T16:00:00.000-08:00]
# earliest_cr_line[T.2004-02-27T16:00:00.000-08:00]
# earliest_cr_line[T.2004-03-26T16:00:00.000-08:00]
# earliest_cr_line[T.2004-03-27T16:00:00.000-08:00]
# earliest_cr_line[T.2004-04-20T17:00:00.000-07:00]
# earliest_cr_line[T.2004-04-25T17:00:00.000-07:00]
# earliest_cr_line[T.2004-04-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-04-27T17:00:00.000-07:00]
# earliest_cr_line[T.2004-05-25T17:00:00.000-07:00]
# earliest_cr_line[T.2004-05-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-06-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-06-27T17:00:00.000-07:00]
# earliest_cr_line[T.2004-07-20T17:00:00.000-07:00]
# earliest_cr_line[T.2004-07-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-08-21T17:00:00.000-07:00]
# earliest_cr_line[T.2004-08-22T17:00:00.000-07:00]
# earliest_cr_line[T.2004-08-24T17:00:00.000-07:00]
# earliest_cr_line[T.2004-08-25T17:00:00.000-07:00]
# earliest_cr_line[T.2004-08-27T17:00:00.000-07:00]
# earliest_cr_line[T.2004-09-24T17:00:00.000-07:00]
# earliest_cr_line[T.2004-09-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-09-27T17:00:00.000-07:00]
# earliest_cr_line[T.2004-10-26T17:00:00.000-07:00]
# earliest_cr_line[T.2004-11-26T16:00:00.000-08:00]
# earliest_cr_line[T.2004-11-27T16:00:00.000-08:00]
# earliest_cr_line[T.2004-12-26T16:00:00.000-08:00]
# earliest_cr_line[T.2004-12-27T16:00:00.000-08:00]
# earliest_cr_line[T.2005-01-24T16:00:00.000-08:00]
# earliest_cr_line[T.2005-01-26T16:00:00.000-08:00]
# earliest_cr_line[T.2005-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.2005-02-21T16:00:00.000-08:00]
# earliest_cr_line[T.2005-02-24T16:00:00.000-08:00]
# earliest_cr_line[T.2005-03-24T16:00:00.000-08:00]
# earliest_cr_line[T.2005-03-27T16:00:00.000-08:00]
# earliest_cr_line[T.2005-04-25T17:00:00.000-07:00]
# earliest_cr_line[T.2005-04-26T17:00:00.000-07:00]
# earliest_cr_line[T
08-27T17:00:00.000-07:00]
# earliest_cr_line[T.2009-11-26T16:00:00.000-08:00]
# earliest_cr_line[T.2009-12-27T16:00:00.000-08:00]
# earliest_cr_line[T.2010-01-26T16:00:00.000-08:00]
# earliest_cr_line[T.2010-05-26T17:00:00.000-07:00]
# earliest_cr_line[T.2010-05-27T17:00:00.000-07:00]
# earliest_cr_line[T.2010-07-24T17:00:00.000-07:00]
# earliest_cr_line[T.2010-09-24T17:00:00.000-07:00]
# earliest_cr_line[T.2010-09-25T17:00:00.000-07:00]
# earliest_cr_line[T.2010-10-25T17:00:00.000-07:00]
# earliest_cr_line[T.2010-10-26T17:00:00.000-07:00]
# earliest_cr_line[T.2010-10-27T17:00:00.000-07:00]
# earliest_cr_line[T.2010-12-27T16:00:00.000-08:00]
# earliest_cr_line[T.2011-02-27T16:00:00.000-08:00]
# earliest_cr_line[T.2011-04-26T17:00:00.000-07:00]
# earliest_cr_line[T.2011-04-27T17:00:00.000-07:00]
# earliest_cr_line[T.2011-08-27T17:00:00.000-07:00]
# earliest_cr_line[T.2011-09-26T17:00:00.000-07:00]
# earliest_cr_line[T.2012-01-27T16:00:00.000-08:00]
# earliest_cr_line[T.2012-03-27T17:00:00.000-07:00]
# earliest_cr_line[T.2012-08-27T17:00:00.000-07:00]
# loan_amnt
# int_rate
# installment
# emp_length
# inq_last_6mths
# pub_rec
# revol_bal
# open_acc
# collections_12_mths_ex_med
# delinq_2yrs
# fico_range_low
# ratio_mth_inc_all_payments
# annual_inc

# %%
df.zip_code
# Out:
# 0      327
# 1      100
# 2      379
# 3      735
# 4      917
# 5      331
# 6      925
# 7      112
# 8      809
# 9      666
# 10     967
# 11     117
# 12     890
# 13     112
# 14     891
# 15     970
# 16     443
# 17     278
# 18     336
# 19     189
# 20     114
# 21     914
# 22     481
# 23     701
# 24     270
# 25     946
# 26     600
# 27     302
# 28     247
# 29     852
#       ...
# 570    351
# 571    301
# 572    014
# 573    301
# 574    325
# 575    117
# 576    655
# 577    154
# 578    913
# 579    480
# 580    295
# 581    210
# 582    921
# 583    800
# 584    765
# 585    554
# 586    303
# 587    945
# 588    983
# 589    028
# 590    104
# 591    775
# 592    750
# 593    770
# 594    334
# 595    068
# 596    328
# 597    306
# 598    480
# 599    460
# Name: zip_code, dtype: object

# %%
len(df.addr_state.value_counts())
# Out:
# 47

# %%
reference_df = pd.read_pickle('cleaned_df.pkl')

# %%
unique_states = reference_df.addr_state.unique()

# %%
import pickle
with open('state_list.pkl', 'wb') as picklefile:
    pickle.dump(list(unique_states.get_values()), picklefile)

# %%
with open('purpose_list.pkl', 'wb') as picklefile:
    pickle.dump(set(unique_states.unique()), picklefile)

# %%
with open('state_list.pkl', 'rb') as picklefile:
    state_list = pickle.load(picklefile)

# %%
unique_states = df.addr_state.unique()

# %%
set(state_list) - set(unique_states.get_values())
# Out:
# {'IA', 'ID', 'NM', 'VT'}

# %%
len(df.purpose.unique())
# Out:
# 12

# %%
df.addr_state = df.addr_state.astype('category')
df.addr_state.cat.add_categories(state_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-748d6ead83f6> in <module>()
#       1 df.addr_state = df.addr_state.astype('category')
# ----> 2 df.addr_state.cat.add_categories(state_list)
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/base.py in f(self, *args, **kwargs)
#     155
#     156             def f(self, *args, **kwargs):
# --> 157                 return self._delegate_method(name, *args, **kwargs)
#     158
#     159             f.__name__ = name
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/categorical.py in _delegate_method(self, name, *args, **kwargs)
#    1757         from pandas import Series
#    1758         method = getattr(self.categorical, name)
# -> 1759         res = method(*args, **kwargs)
#    1760         if not res is None:
#    1761             return Series(res, index=self.index)
#
# /Users/Will/anaconda/envs/py34/lib/python3.4/site-packages/pandas/core/categorical.py in add_categories(self, new_categories, inplace)
#     736         if len(already_included) != 0:
#     737             msg = "new categories must not include old categories: %s" % str(already_included)
# --> 738             raise ValueError(msg)
#     739         new_categories = list(self._categories) + list(new_categories)
#     740         cat = self if inplace else self.copy()
#
# ValueError: new categories must not include old categories: {'OR', 'IL', 'OK', 'WI', 'DE', 'HI', 'KS', 'LA', 'NV', 'IN', 'MD', 'NE', 'FL', 'AR', 'WV', 'MO', 'SD', 'VA', 'CT', 'KY', 'CO', 'ME', 'MT', 'OH', 'WA', 'TX', 'AL', 'AZ', 'RI', 'AK', 'MI', 'WY', 'PA', 'NC', 'CA', 'DC', 'MN', 'NJ', 'MS', 'NY', 'NH', 'SC', 'GA', 'TN', 'UT', 'MA'}

# %%
state_list
# Out:
# ['AZ',
#  'GA',
#  'IL',
#  'CA',
#  'OR',
#  'NC',
#  'TX',
#  'VA',
#  'MO',
#  'CT',
#  'UT',
#  'FL',
#  'NY',
#  'PA',
#  'MN',
#  'NJ',
#  'KY',
#  'OH',
#  'SC',
#  'RI',
#  'LA',
#  'MA',
#  'WA',
#  'WI',
#  'AL',
#  'CO',
#  'KS',
#  'NV',
#  'AK',
#  'MD',
#  'WV',
#  'VT',
#  'MI',
#  'DC',
#  'SD',
#  'NH',
#  'AR',
#  'NM',
#  'MT',
#  'HI',
#  'WY',
#  'OK',
#  'DE',
#  'MS',
#  'TN',
#  'IA',
#  'NE',
#  'ID',
#  'IN',
#  'ME']

# %%
df.addr_state
# Out:
# 0      FL
# 1      NY
# 2      TN
# 3      OK
# 4      CA
# 5      FL
# 6      CA
# 7      NY
# 8      CO
# 9      KS
# 10     HI
# 11     NY
# 12     NV
# 13     NY
# 14     NV
# 15     OR
# 16     OH
# 17     NC
# 18     FL
# 19     PA
# 20     NY
# 21     CA
# 22     MI
# 23     LA
# 24     NC
# 25     CA
# 26     IL
# 27     GA
# 28     WV
# 29     AZ
#        ..
# 570    AL
# 571    GA
# 572    MA
# 573    GA
# 574    FL
# 575    NY
# 576    MO
# 577    PA
# 578    CA
# 579    MI
# 580    SC
# 581    MD
# 582    CA
# 583    CO
# 584    TX
# 585    MN
# 586    GA
# 587    CA
# 588    WA
# 589    RI
# 590    NY
# 591    TX
# 592    TX
# 593    TX
# 594    FL
# 595    CT
# 596    FL
# 597    GA
# 598    MI
# 599    IN
# Name: addr_state, dtype: object

# %%
df.addr_state.cat.
