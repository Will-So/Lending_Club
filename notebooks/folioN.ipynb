# %% [markdown]
# Only the seller has a 1% fee.
#
# Keep the data in the support of the engine.

# %%
import sys

# %%
sys.path.append('/Users/Will/Devel/metis/lc/')

# %%
from app.config import  main_config

# %%
main_config.keys()
# Out:
# dict_keys(['investor_id', 'credentials', 'portfolio_id'])

# %%
import pandas as pd

# %%
import requests

# %%
df = pd.read_csv('http://www.foliofnapi.com/get.php?status=current&format=CSV')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-29-f81a81c06fd0> in <module>()
# ----> 1 df = pd.read_csv('http://www.foliofnapi.com/get.php?status=current&format=CSV')
#
# ...

# %%
r = requests.get('http://www.foliofnapi.com/get.php?status=current&format=CSV')

# %%
r.text
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n    <head>\r\n    \t<meat name="ROBOTS" content="NOINDEX, NOFOLLOW">\r\n        <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n        <title></title>\r\n        <title>FOLIOfn Lending Club API</title>\r\n\t    <meta name="description" content="FOLIOfn Lending Club API" />\r\n\t    <meta name="keywords" content="CSV and JSON feeds for Lending Club\'s Trading Platform FOLIOfn" />\r\n\t    <meta property="og:url" content="http://www.foliofnapi.com">\r\n\t    <meta property="og:type" content="website">\r\n\t    <meta property="og:title" content="FOLIOfn Lending Club API">\r\n\t    <meta property="og:image" content="http://www.foliofnapi.com/images/api.png">\r\n\t    <meta property="og:description" content="CSV and JSON feeds for Lending Club\'s Trading Platform FOLIOfn">\r\n\t    <link rel="shortcut icon" href="images/api.png"/>\r\n    </head>\r\n    <body>\r\n    \tloanId,noteId,orderId,outstandingPrincipal,accruedInterest,status,as
# ...

# %%
'http://www.foliofnapi.com/get.php?status=current'
